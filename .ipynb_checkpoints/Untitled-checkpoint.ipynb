# %%
import re
import pandas as pd
import numpy as np

df = pd.read_csv("GSAF5.csv", encoding="ISO-8859-1")
df
#(encoding="ISO-8859-1") = encodes what it refers to as "Latin alphabet no. 1", consisting of 
#191 characters from the Latin script. This character-encoding scheme is used throughout the Americas,
#Western Europe, Oceania, and much of Africa. It is also commonly used in most standard romanizations 
#of East-Asian languages. With this encode we are able to read this and many other files.
# Out:
#        Case Number         Date  Year        Type             Country  \
# 0     2016.09.18.c    18-Sep-16  2016  Unprovoked                 USA
# 1     2016.09.18.b    18-Sep-16  2016  Unprovoked                 USA
# 2     2016.09.18.a    18-Sep-16  2016  Unprovoked                 USA
# 3       2016.09.17    17-Sep-16  2016  Unprovoked           AUSTRALIA
# 4       2016.09.15    16-Sep-16  2016  Unprovoked           AUSTRALIA
# ...            ...          ...   ...         ...                 ...
# 5987       ND.0005  Before 1903     0  Unprovoked           AUSTRALIA
# 5988       ND.0004  Before 1903     0  Unprovoked           AUSTRALIA
# 5989       ND.0003    1900-1905     0  Unprovoked                 USA
# 5990       ND.0002    1883-1889     0  Unprovoked              PANAMA
# 5991       ND.0001    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0               Florida     New Smyrna Beach, Volusia County       Surfing
# 1               Florida     New Smyrna Beach, Volusia County       Surfing
# 2               Florida     New Smyrna Beach, Volusia County       Surfing
# 3              Victoria                     Thirteenth Beach       Surfing
# 4              Victoria                          Bells Beach       Surfing
# ...                 ...                                  ...           ...
# 5987  Western Australia                          Roebuck Bay        Diving
# 5988  Western Australia                                  NaN  Pearl diving
# 5989     North Carolina                       Ocracoke Inlet      Swimming
# 5990                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 5991   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   ...   Species   \
# 0                      male    M  ...        NaN
# 1            Chucky Luciano    M  ...        NaN
# 2                      male    M  ...        NaN
# 3           Rory Angiolella    M  ...        NaN
# 4                      male    M  ...  2 m shark
# ...                     ...  ...  ...        ...
# 5987                   male    M  ...        NaN
# 5988                  Ahmun    M  ...        NaN
# 5989  Coast Guard personnel    M  ...        NaN
# 5990        Jules Patterson    M  ...        NaN
# 5991                   male    M  ...        NaN
#
#                      Investigator or Source                             pdf  \
# 0               Orlando Sentinel, 9/19/2016            2016.09.18.c-NSB.pdf
# 1               Orlando Sentinel, 9/19/2016        2016.09.18.b-Luciano.pdf
# 2               Orlando Sentinel, 9/19/2016            2016.09.18.a-NSB.pdf
# 3                        The Age, 9/18/2016       2016.09.17-Angiolella.pdf
# 4                        The Age, 9/16/2016       2016.09.16-BellsBeach.pdf
# ...                                     ...                             ...
# 5987       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 5988  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 5989   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 5990                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 5991                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 5987  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5988  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5989  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5990  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5991  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.b
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.a
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.17
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2016.09.16
# ...                                                 ...           ...
# 5987  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 5988  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 5989  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 5990  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 5991  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0     2016.09.18.c           5993         NaN         NaN
# 1     2016.09.18.b           5992         NaN         NaN
# 2     2016.09.18.a           5991         NaN         NaN
# 3       2016.09.17           5990         NaN         NaN
# 4       2016.09.15           5989         NaN         NaN
# ...            ...            ...         ...         ...
# 5987       ND.0005              6         NaN         NaN
# 5988       ND.0004              5         NaN         NaN
# 5989       ND.0003              4         NaN         NaN
# 5990       ND.0002              3         NaN         NaN
# 5991       ND.0001              2         NaN         NaN
#
# [5992 rows x 24 columns]

# %%
#thinking about our hypothesis where we will try to demonstrate that shark's attacks on human 
#beings are increasing because humans invade their habitat more and more for different reasons.

#first we will start by cleaning our data and get from it the most important we think we will need
#for our investigation.

#Creating new DataFrame without duplicated columns or innecesary for our investigation:
dfa = df.drop(columns=["Case Number", "pdf", "href formula", "href", "Case Number.1", "Case Number.2",
                       "Unnamed: 22", "Unnamed: 23"])

#rearranging DataFrame:
#change columns order:
cols=list(dfa.columns.values)
dfa = dfa[[cols[-1]] + cols[0:-1]]

#change column Name:
x = {"original order":"Case Number"}
dfa = dfa.rename(columns=x)

#define specific data to work on our hypothesis:
dfa.loc[dfa["Type"]==" ", "Type"] = "Unknown"
dfa.loc[dfa["Name"]=="male", "Name"] = "Unknown"
dfa.loc[dfa["Name"]=="female", "Name"] = "Unknown"
dfa.loc[dfa["Name"]=="boy", "Name"] = "Unknown"
dfa.loc[dfa["Name"]==" ", "Name"] = "Unknown"
dfa.loc[dfa["Activity"]==" ", "Activity"] = "Unknown"
dfa.loc[dfa["Case Number"]==" ", "Case Number"] = "Unknown"
dfa.loc[dfa["Date"]==" ", "Date"] = "Unknown"
dfa.loc[dfa["Year"]==" ", "Year"] = "Unknown"
dfa.loc[dfa["Country"]==" ", "Country"] = "Unknown"
dfa.loc[dfa["Area"]==" ", "Area"] = "Unknown"
dfa.loc[dfa["Location"]==" ", "Location"] = "Unknown"
dfa.loc[dfa["Age"]==" ", "Age"] = "Unknown"
dfa.loc[dfa["Injury"]==" ", "Injury"] = "Unknown"
dfa.loc[dfa["Fatal (Y/N)"]==" ", "Fatal (Y/N)"] = "Unknown"
dfa.loc[dfa["Time"]==" ", "Time"] = "Unknown"
dfa.loc[dfa["Investigator or Source"]==" ", "Investigator or Source"] = "Unknown"
dfa.replace(np.nan, "Unknown")
dfa["50 Years"] = pd.cut(dfa.Year,bins=[1549,1599,1659,1699,1759,1799,1859,1899,1959,1999,2059], 
                         labels=range(1550,2050,50))
for x in Name:
    if
# Out:
#     Case Number       Date  Year        Type               Country  \
# 0          5993  18-Sep-16  2016  Unprovoked                   USA
# 1          5992  18-Sep-16  2016  Unprovoked                   USA
# 2          5991  18-Sep-16  2016  Unprovoked                   USA
# 3          5990  17-Sep-16  2016  Unprovoked             AUSTRALIA
# 4          5989  16-Sep-16  2016  Unprovoked             AUSTRALIA
# ..          ...        ...   ...         ...                   ...
# 95         5898  28-Jan-16  2016  Unprovoked                   USA
# 96         5897  25-Jan-16  2016  Unprovoked                   USA
# 97         5896  24-Jan-16  2016  Unprovoked                   USA
# 98         5895  24-Jan-16  2016        Boat  UNITED ARAB EMIRATES
# 99         5894  23-Jan-16  2016  Unprovoked                   USA
#
#                 Area                          Location         Activity  \
# 0            Florida  New Smyrna Beach, Volusia County          Surfing
# 1            Florida  New Smyrna Beach, Volusia County          Surfing
# 2            Florida  New Smyrna Beach, Volusia County          Surfing
# 3           Victoria                  Thirteenth Beach          Surfing
# 4           Victoria                       Bells Beach          Surfing
# ..               ...                               ...              ...
# 95            Hawaii                Hanalei Bay, Kauai          Surfing
# 96            Hawaii              Hanalei Bay, Kauai,           Surfing
# 97             Texas                      Off Surfside     Spearfishing
# 98  Fujairah Emirate             35 miles off Fujairah          Fishing
# 99            Hawaii                Wailea Beach, Maui  Paddle boarding
#
#                                            Name Sex   Age  \
# 0                                       Unknown    M   16
# 1                                Chucky Luciano    M   36
# 2                                       Unknown    M   43
# 3                               Rory Angiolella    M  NaN
# 4                                       Unknown    M  NaN
# ..                                          ...  ...  ...
# 95                                      Unknown    M  NaN
# 96                                 Kaya Waldman    F   15
# 97                                   Keith Love    M  NaN
# 98  Occupants: Hamza Humaid Al Sahraa & 5 crew    M  NaN
# 99                                   Matt Mason    M   48
#
#                                                Injury Fatal (Y/N)  \
# 0                               Minor injury to thigh           N
# 1                                Lacerations to hands           N
# 2                            Lacerations to lower leg           N
# 3                        Struck by fin on chest & leg           N
# 4               No injury: Knocked off board by shark           N
# ..                                                ...         ...
# 95                          Lacerations to both hands           N
# 96                                          No injury           N
# 97  Bruised ribs & tail bone, speargun broken and ...           N
# 98      No injury to occupants, shark leapt into boat           N
# 99                                          No injury           N
#
#              Time          Species          Investigator or Source 50 Years
# 0           13h00               NaN    Orlando Sentinel, 9/19/2016     2000
# 1           11h00               NaN    Orlando Sentinel, 9/19/2016     2000
# 2           10h43               NaN    Orlando Sentinel, 9/19/2016     2000
# 3             NaN               NaN             The Age, 9/18/2016     2000
# 4             NaN         2 m shark             The Age, 9/16/2016     2000
# ..            ...               ...                            ...      ...
# 95          14h00    Reef shark, 5'               KHON2. 1/28/2016     2000
# 96          11h30               NaN    The Garden Island, 2/2/2016     2000
# 97  09h30 / 10h00   Bull sharks x 2                        K. Love     2000
# 98            NaN        Mako shark           Gulf News, 1/25/2016     2000
# 99        Morning  Tiger shark, 14'  Grand Forks Herald, 1/27/2915     2000
#
# [100 rows x 17 columns]

# %%
dfb= dfa.reset_index()
x = {"index":"Attacks Summary"}
dfb = dfb.rename(columns=x)
dfb
# Out:
#       Attacks Summary  Case Number         Date  Year        Type  \
# 0                   0         5993    18-Sep-16  2016  Unprovoked
# 1                   1         5992    18-Sep-16  2016  Unprovoked
# 2                   2         5991    18-Sep-16  2016  Unprovoked
# 3                   3         5990    17-Sep-16  2016  Unprovoked
# 4                   4         5989    16-Sep-16  2016  Unprovoked
# ...               ...          ...          ...   ...         ...
# 5987             5987            6  Before 1903     0  Unprovoked
# 5988             5988            5  Before 1903     0  Unprovoked
# 5989             5989            4    1900-1905     0  Unprovoked
# 5990             5990            3    1883-1889     0  Unprovoked
# 5991             5991            2    1845-1853     0  Unprovoked
#
#                  Country               Area  \
# 0                    USA            Florida
# 1                    USA            Florida
# 2                    USA            Florida
# 3              AUSTRALIA           Victoria
# 4              AUSTRALIA           Victoria
# ...                  ...                ...
# 5987           AUSTRALIA  Western Australia
# 5988           AUSTRALIA  Western Australia
# 5989                 USA     North Carolina
# 5990              PANAMA                NaN
# 5991  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 0        New Smyrna Beach, Volusia County       Surfing
# 1        New Smyrna Beach, Volusia County       Surfing
# 2        New Smyrna Beach, Volusia County       Surfing
# 3                        Thirteenth Beach       Surfing
# 4                             Bells Beach       Surfing
# ...                                   ...           ...
# 5987                          Roebuck Bay        Diving
# 5988                                  NaN  Pearl diving
# 5989                       Ocracoke Inlet      Swimming
# 5990                 Panama Bay 8ºN, 79ºW           NaN
# 5991  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 0                   Unknown    M   16
# 1            Chucky Luciano    M   36
# 2                   Unknown    M   43
# 3           Rory Angiolella    M  NaN
# 4                   Unknown    M  NaN
# ...                     ...  ...  ...
# 5987                Unknown    M  NaN
# 5988                  Ahmun    M  NaN
# 5989  Coast Guard personnel    M  NaN
# 5990        Jules Patterson    M  NaN
# 5991                Unknown    M   15
#
#                                                  Injury Fatal (Y/N)   Time  \
# 0                                 Minor injury to thigh           N  13h00
# 1                                  Lacerations to hands           N  11h00
# 2                              Lacerations to lower leg           N  10h43
# 3                          Struck by fin on chest & leg           N    NaN
# 4                 No injury: Knocked off board by shark           N    NaN
# ...                                                 ...         ...    ...
# 5987                                              FATAL           Y    NaN
# 5988                                              FATAL           Y    NaN
# 5989                                              FATAL           Y    NaN
# 5990                                              FATAL           Y    NaN
# 5991  FATAL. "Shark bit him in half, carrying away t...           Y    NaN
#
#        Species                  Investigator or Source 50 Years
# 0           NaN            Orlando Sentinel, 9/19/2016     2000
# 1           NaN            Orlando Sentinel, 9/19/2016     2000
# 2           NaN            Orlando Sentinel, 9/19/2016     2000
# 3           NaN                     The Age, 9/18/2016     2000
# 4     2 m shark                     The Age, 9/16/2016     2000
# ...         ...                                    ...      ...
# 5987        NaN       H. Taunton; N. Bartlett,  p. 234      NaN
# 5988        NaN  H. Taunton; N. Bartlett,  pp. 233-234      NaN
# 5989        NaN   F. Schwartz, p.23; C. Creswell, GSAF      NaN
# 5990        NaN                    The Sun, 10/20/1938      NaN
# 5991        NaN                             S.W. Baker      NaN
#
# [5992 rows x 18 columns]

# %%
#As we can see in the graphic the attacks multiply exponentially every 50 years 
dfb[["50 Years","Attacks Summary"]]["50 Years"].value_counts().plot.bar()

# %%
#dfb[dfb['Type'].str.contains('UnProvocked')].count()
#dfb["Activity"].str.contains("Surfing").count()
#dfb["50 Years",["Activity"].str.contains("Surfing")]["50 Years"]
#.value_counts().plot.bar()
stats = dfb.Type.describe().T
dfb["Type"].count().plot()
#(kind="pie")
stats
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-3305ebfbfe5b> in <module>
#       4 #.value_counts().plot.bar()
#       5 stats = dfb.Type.describe().T
# ----> 6 dfb["Type"].count().plot()
#       7 #(kind="pie")
#       8 stats
#
# AttributeError: 'numpy.int32' object has no attribute 'plot'

# %%
dfa.to_csv("", index=False)
